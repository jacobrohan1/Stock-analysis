# %%
import pandas as pd 
import numpy as np
import pandas_datareader.data as web 
import datetime
import matplotlib.pyplot as plt

# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
start = datetime.datetime(2021,1,1)
end = datetime.datetime(2022,6,30)

# %%
amazon = web.DataReader('AMZN','yahoo',start,end)

# %%
amazon
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-12-31  164.145996  162.059998  163.750000  162.846497  59144000.0
# 2021-01-04  163.600006  157.201004  163.500000  159.331497  88228000.0
# 2021-01-05  161.169006  158.253006  158.300507  160.925507  53110000.0
# 2021-01-06  159.875504  156.557999  157.324005  156.919006  87896000.0
# 2021-01-07  160.427002  157.750000  157.850006  158.108002  70290000.0
# ...                ...         ...         ...         ...         ...
# 2022-06-24  116.709999  111.430000  112.379997  116.459999  69867600.0
# 2022-06-27  117.980003  112.699997  117.089996  113.220001  62133200.0
# 2022-06-28  114.849998  107.040001  113.500000  107.400002  74942900.0
# 2022-06-29  110.989998  106.910004  107.379997  108.919998  66375300.0
# 2022-06-30  108.180000  102.519997  108.110001  106.209999  97679400.0
#
#              Adj Close
# Date
# 2020-12-31  162.846497
# 2021-01-04  159.331497
# 2021-01-05  160.925507
# ...

# %%
amazon['Open'].plot(label = 'Amzn Open Price', figsize = (15,7))
amazon['Close'].plot(label = 'Amzn Close Price')
amazon['High'].plot(label = 'Amzn High Price')
amazon['Low'].plot(label = 'Amzn Low Price')
plt.legend()
plt.show()

# %%
amazon['Volume'].plot(label = 'Volume Traded', figsize = (17,5))
plt.title('Volume Traded by Amazon')
# Out:
# Text(0.5, 1.0, 'Volume Traded by Amazon')

# %%
google = web.DataReader('Googl','yahoo',start,end)
apple = web.DataReader('AAPL','yahoo',start,end)
micro = web.DataReader('MSFT','yahoo',start,end)
amazon = web.DataReader('AMZN','yahoo',start,end)

# %%
google.to_csv('google_stocks.csv')
apple.to_csv('apple_stocks.csv')
micro.to_csv('microsoft_stocks.csv')
amazon.to_csv('amazon_stocks.csv')

# %%
google.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-12-31  87.875000  86.804497  86.863503  87.632004  21070000  87.632004
# 2021-01-04  88.124496  85.357002  88.000000  86.306503  37324000  86.306503
# 2021-01-05  87.341499  85.845001  86.254501  87.002502  20360000  87.002502
# 2021-01-06  87.198502  84.805000  85.013000  86.143997  46588000  86.143997
# 2021-01-07  88.890999  86.337997  86.337997  88.717003  41936000  88.717003

# %% [markdown]
# # Open Prices of Amazon , Google , Apple , Microsoft

# %%
apple['Open'].plot(label = 'Apple',figsize = (15,7))
google['Open'].plot(label = 'Google')
micro['Open'].plot(label = 'Microsoft')
amazon['Open'].plot(label = 'Amazon')
plt.ylabel('Stock Price')
plt.xlabel('Date')
plt.title('Stock prices of Apple,Microsof,Google,Amazon')
plt.legend()

# %% [markdown]
# # Volume Traded

# %%
amazon['Volume'].plot(label = 'Volume Traded by Amazon', figsize = (15,7))
apple['Volume'].plot(label = 'Apple')
micro['Volume'].plot(label = 'Microsoft')
google['Volume'].plot(label = 'Google')
plt.ylabel('Volume Traded')
plt.legend()

# %%
amazon.iloc[[amazon['Volume'].argmax()]]
# Out:
#                   High      Low        Open       Close       Volume  \
# Date
# 2022-04-29  130.761002  121.625  129.848999  124.281502  272662000.0
#
#              Adj Close
# Date
# 2022-04-29  124.281502

# %%
amazon.iloc[320:370]['Open'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# # Market Cap

# %%
amazon['Total Traded'] = amazon['Open'] * amazon['Volume']
micro['Total Traded'] = micro['Open'] * micro['Volume']
apple['Total Traded'] = apple['Open'] * apple['Volume']
google['Total Traded'] = google['Open'] * google['Volume']

# %%
amazon['Total Traded'].plot(label ='Amazon', figsize = (17,5))
micro['Total Traded'].plot(label ='Microsoft')
apple['Total Traded'].plot(label ='Apple')
google['Total Traded'].plot(label ='Google')
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
amazon.iloc[[amazon['Total Traded'].argmax()]]
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-02-04  161.199997  150.608002  155.606506  157.639496  253456000.0
#
#              Adj Close  Total Traded
# Date
# 2022-02-04  157.639496  3.943940e+10

# %%
amazon.iloc[[amazon['Total Traded'].argmax()]]
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-02-04  161.199997  150.608002  155.606506  157.639496  253456000.0
#
#              Adj Close  Total Traded
# Date
# 2022-02-04  157.639496  3.943940e+10

# %% [markdown]
# # Amazon shares closed down 14% on Friday, the worst day since 2006.
# The company on Thursday gave lighter-than-expected revenue guidance for the current quarter.
# Amazon also recorded a $7.6 billion loss on its investment in electric vehicle maker Rivian, which lost more than half its value in the quarter.

# %% [markdown]
# # Moving Average of Various Stocks

# %%
google['Open'].plot(figsize=(17,5))
google['Moving Average 50'] = google['Open'].rolling(50).mean()
plt.ylabel('Opening Price')
plt.title('Moving Average for Google')
google['Moving Average 50'].plot(figsize=(17,5))
plt.legend()

# %%
amazon['Open'].plot(figsize=(17,5))
amazon['Moving Average 50'] = amazon['Open'].rolling(50).mean()
plt.ylabel('Opening prices')
plt.title('Moving Average for Amazon')
amazon['Moving Average 50'].plot()
plt.legend()

# %%
apple['Open'].plot(figsize=(17,5))
apple['Moving Average 50'] = apple['Open'].rolling(50).mean()
plt.ylabel('Opening Prices')
plt.title('Moving Average for Apple')
apple['Moving Average 50'].plot()
plt.legend()

# %%
micro['Open'].plot(figsize=(17,5))
micro['Moving Average 50'] = micro['Open'].rolling(50).mean()
micro['Moving Average 100'] = micro['Open'].rolling(100).mean()
micro['Moving Average 100'].plot()
micro['Moving Average 50'].plot()
plt.ylabel('Opening Prices')
plt.title('Moving Average of 50 for Microsoft')
plt.legend()

# %% [markdown]
# # Daily Return

# %%
google['Trend'] = google['Close'] - google['Open']
google['Trend'].plot(figsize = (17,5))
google['Moving Average of Daily Return'] = google['Trend'].rolling(50).mean()
google['Moving Average of Daily Return'].plot()
plt.legend()
plt.title('Daily Return for Google')
plt.ylabel('Daily Return')
# Out:
# Text(0, 0.5, 'Daily Return')

# %%
apple['Trend'] = apple['Close'] - apple['Open']
apple['Trend'].plot(figsize = (17,5))
apple['Moving Average of Daily Return'] = apple['Trend'].rolling(50).mean()
apple['Moving Average of Daily Return'].plot()
plt.ylabel('Daily Returns')
plt.title('Daily Returns of Apple')
plt.legend()

# %%
micro['Trend'] = micro['Close'] - micro['Open']
micro['Trend'].plot(figsize = (17,5))
micro['Moving Average of Daily Return'] = micro['Trend'].rolling(50).mean()
micro['Moving Average of Daily Return'].plot()
plt.ylabel('Daily Returns')
plt.title('Daily Returns of Microsoft')
plt.legend()

# %%
amazon['Trend'] = amazon['Close'] - amazon['Open']
amazon['Trend'].plot(figsize = (17,5))
amazon['Moving Average of Daily Return of 50'] = amazon['Trend'].rolling(50).mean()
amazon['Moving Average of Daily Return of 50'].plot()
plt.ylabel('Daily Returns')
plt.title('Daily Returns of Amazon')
plt.legend()

# %%
google.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2020-12-31  87.875000  86.804497  86.863503  87.632004  21070000  87.632004
# 2021-01-04  88.124496  85.357002  88.000000  86.306503  37324000  86.306503
# 2021-01-05  87.341499  85.845001  86.254501  87.002502  20360000  87.002502
# 2021-01-06  87.198502  84.805000  85.013000  86.143997  46588000  86.143997
# 2021-01-07  88.890999  86.337997  86.337997  88.717003  41936000  88.717003
#
#             Total Traded  Moving Average 50  Daily Return  \
# Date
# 2020-12-31  1.830214e+09                NaN      0.768501
# 2021-01-04  3.284512e+09                NaN     -1.693497
# 2021-01-05  1.756142e+09                NaN      0.748001
# 2021-01-06  3.960586e+09                NaN      1.130997
# 2021-01-07  3.620670e+09                NaN      2.379005
#
#             Moving Average of Daily Return     Trend
# Date
# 2020-12-31                             NaN  0.768501
# ...

# %% [markdown]
# # Corelation between the Daily Returns between different stocks

# %%
from pandas.plotting import scatter_matrix

# %%
stock_comp = pd.concat([amazon['Trend'], apple['Trend'], micro['Trend'],google['Trend']],axis = 1)
stock_comp.columns = ['Amazon Trend','Apple Trend', 'Microsoft Trend','Google Trend']

# %%
scatter_matrix(stock_comp, figsize = (8,8), hist_kwds = {'bins': 50})
# Out:
# array([[<AxesSubplot: xlabel='Amazon Trend', ylabel='Amazon Trend'>,
#         <AxesSubplot: xlabel='Apple Trend', ylabel='Amazon Trend'>,
#         <AxesSubplot: xlabel='Microsoft Trend', ylabel='Amazon Trend'>,
#         <AxesSubplot: xlabel='Google Trend', ylabel='Amazon Trend'>],
#        [<AxesSubplot: xlabel='Amazon Trend', ylabel='Apple Trend'>,
#         <AxesSubplot: xlabel='Apple Trend', ylabel='Apple Trend'>,
#         <AxesSubplot: xlabel='Microsoft Trend', ylabel='Apple Trend'>,
#         <AxesSubplot: xlabel='Google Trend', ylabel='Apple Trend'>],
#        [<AxesSubplot: xlabel='Amazon Trend', ylabel='Microsoft Trend'>,
#         <AxesSubplot: xlabel='Apple Trend', ylabel='Microsoft Trend'>,
#         <AxesSubplot: xlabel='Microsoft Trend', ylabel='Microsoft Trend'>,
#         <AxesSubplot: xlabel='Google Trend', ylabel='Microsoft Trend'>],
#        [<AxesSubplot: xlabel='Amazon Trend', ylabel='Google Trend'>,
# ...
